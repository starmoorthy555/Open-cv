# %% [markdown]
# cv2.image reading process

# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread("/content/cat.6.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x303 at 0x7FBEC92C8B10>

# %% [markdown]
# shape of our image

# %%
image.shape
# Out:
# (303, 400, 3)

# %% [markdown]
# resize our image

# %%
image = cv2.resize(image,(250,250))
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FBEC92DA0D0>
# (250, 250, 3)

# %% [markdown]
# make face dedection using xml file

# %%
import cv2
from google.colab.patches import cv2_imshow
image1 = cv2.imread("/content/cat.6.jpg")
cv2_imshow(image)
classifier = cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cordinates = classifier.detectMultiScale(gray_image)
print(cordinates)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FBEC8FF4750>
# [[139  37  92  92]]

# %%
for (x,y,w,h) in cordinates:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),3)
  cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FBEC8FF4490>
